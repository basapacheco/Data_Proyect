# %%
#Librerias
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from plotly.plotly import iplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-d25e97a9fb4d> in <module>
#       5 import seaborn as sns
#       6 from collections import Counter
# ----> 7 from plotly.plotly import iplot
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/plotly/__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ----> 4 _chart_studio_error("plotly")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/_plotly_future_/__init__.py in _chart_studio_error(submodule)
#      41
#      42 def _chart_studio_error(submodule):
# ---> 43     raise ImportError(
#      44         """
#      45 The plotly.{submodule} module is deprecated,
#
# ImportError:
# The plotly.plotly module is deprecated,
# please install the chart-studio package and use the
# chart_studio.plotly module instead.

# %%
##LIMPIEZA DE DATOS Y CREACIÓN DE DATAFRAME

# %%
movies = pd.read_csv('../Data_Proyect/Dataset/IMDb movies.csv', low_memory=False)
movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 23710 non-null  object
#  17  usa_gross_income       15326 non-null  object
#  18  worlwide_gross_income  31016 non-null  object
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 14.4+ MB

# %%
ratings = pd.read_csv('../Data_Proyect/Dataset/IMDb_ratings.csv', low_memory=False)
ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# 1              6.0        57       18       58      137      139  ...
# 2              6.0         6        6       17       44       52  ...
# 3              5.0        15        8       16       62       98  ...
# 4              7.0       210      225      436      641      344  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 85850          6.0        13        9       26       65      104  ...
# 85851          8.0        65      139      288      170       42  ...
# 85852          8.0        63       29       61       61       31  ...
# 85853         10.0       176        0        2        2        1  ...
# 85854          7.0         4        4       21       35       27  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         5.7                 13.0                     4.5
# 1                         6.2                 23.0                     6.6
# 2                         5.8                  4.0                     6.8
# 3                         5.5                 14.0                     6.1
# 4                         7.3                 82.0                     7.4
# ...                       ...                  ...                     ...
# 85850                     5.7                 11.0                     5.0
# 85851                     8.0                 47.0                     7.3
# 85852                     NaN                  NaN                     NaN
# 85853                     NaN                  NaN                     7.0
# 85854                     6.8                  4.0                     7.5
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                      4.0                    5.7                  34.0
# 1                     14.0                    6.4                  66.0
# 2                      7.0                    5.4                  32.0
# 3                     21.0                    4.9                  57.0
# 4                     77.0                    6.9                 139.0
# ...                    ...                    ...                   ...
# 85850                  2.0                    5.5                  12.0
# 85851                 30.0                    7.0                   6.0
# 85852                  NaN                    1.0                   1.0
# 85853                  1.0                    4.0                   3.0
# 85854                  4.0                    7.0                   4.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.4             51.0                   6.0
# 1                   6.0             96.0                   6.2
# 2                   6.2             31.0                   5.9
# 3                   5.5            207.0                   4.7
# 4                   7.0            488.0                   7.0
# ...                 ...              ...                   ...
# 85850               6.3             22.0                   5.3
# 85851               6.8             13.0                   7.7
# 85852               NaN              NaN                   2.0
# 85853               1.7              5.0                   5.8
# 85854               6.7             13.0                   6.7
#
#        non_us_voters_votes
# 0                     70.0
# 1                    331.0
# 2                    123.0
# 3                    105.0
# 4                   1166.0
# ...                    ...
# 85850                214.0
# 85851                388.0
# 85852                  2.0
# 85853                  5.0
# 85854                 60.0
#
# [85855 rows x 49 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_title_id              85855 non-null  object
#  1   weighted_average_vote      85855 non-null  float64
#  2   total_votes                85855 non-null  int64
#  3   mean_vote                  85855 non-null  float64
#  4   median_vote                85855 non-null  float64
#  5   votes_10                   85855 non-null  int64
#  6   votes_9                    85855 non-null  int64
#  7   votes_8                    85855 non-null  int64
#  8   votes_7                    85855 non-null  int64
#  9   votes_6                    85855 non-null  int64
#  10  votes_5                    85855 non-null  int64
#  11  votes_4                    85855 non-null  int64
#  12  votes_3                    85855 non-null  int64
#  13  votes_2                    85855 non-null  int64
#  14  votes_1                    85855 non-null  int64
#  15  allgenders_0age_avg_vote   33359 non-null  float64
#  16  allgenders_0age_votes      33359 non-null  float64
#  17  allgenders_18age_avg_vote  85149 non-null  float64
#  18  allgenders_18age_votes     85149 non-null  float64
#  19  allgenders_30age_avg_vote  85845 non-null  float64
#  20  allgenders_30age_votes     85845 non-null  float64
#  21  allgenders_45age_avg_vote  85775 non-null  float64
#  22  allgenders_45age_votes     85775 non-null  float64
#  23  males_allages_avg_vote     85854 non-null  float64
#  24  males_allages_votes        85854 non-null  float64
#  25  males_0age_avg_vote        27411 non-null  float64
#  26  males_0age_votes           27411 non-null  float64
#  27  males_18age_avg_vote       84390 non-null  float64
#  28  males_18age_votes          84390 non-null  float64
#  29  males_30age_avg_vote       85843 non-null  float64
#  30  males_30age_votes          85843 non-null  float64
#  31  males_45age_avg_vote       85754 non-null  float64
#  32  males_45age_votes          85754 non-null  float64
#  33  females_allages_avg_vote   85774 non-null  float64
#  34  females_allages_votes      85774 non-null  float64
#  35  females_0age_avg_vote      22117 non-null  float64
#  36  females_0age_votes         22117 non-null  float64
#  37  females_18age_avg_vote     79334 non-null  float64
#  38  females_18age_votes        79334 non-null  float64
#  39  females_30age_avg_vote     84911 non-null  float64
#  40  females_30age_votes        84911 non-null  float64
#  41  females_45age_avg_vote     83057 non-null  float64
#  42  females_45age_votes        83057 non-null  float64
#  43  top1000_voters_rating      85176 non-null  float64
#  44  top1000_voters_votes       85176 non-null  float64
#  45  us_voters_rating           85646 non-null  float64
#  46  us_voters_votes            85646 non-null  float64
#  47  non_us_voters_rating       85854 non-null  float64
#  48  non_us_voters_votes        85854 non-null  float64
# dtypes: float64(37), int64(11), object(1)
# memory usage: 32.1+ MB

# %%
titles = pd.read_csv('../Data_Proyect/Dataset/IMDb title_principals.csv', low_memory=False)
titles
# Out:
#        imdb_title_id  ordering imdb_name_id         category    job  \
# 0          tt0000009         1    nm0063086          actress    NaN
# 1          tt0000009         2    nm0183823            actor    NaN
# 2          tt0000009         3    nm1309758            actor    NaN
# 3          tt0000009         4    nm0085156         director    NaN
# 4          tt0000574         1    nm0846887          actress    NaN
# ...              ...       ...          ...              ...    ...
# 835508     tt9914942         6    nm3678448           writer    NaN
# 835509     tt9914942         7    nm9361716           writer  novel
# 835510     tt9914942         8    nm2262072         composer    NaN
# 835511     tt9914942         9    nm1966322  cinematographer    NaN
# 835512     tt9914942        10    nm0739828           editor    NaN
#
#                                                characters
# 0                ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                        ["Mr. Hamilton"]
# 2       ["Chauncey Depew - the Director of the New Yor...
# 3                                                     NaN
# 4                                          ["Kate Kelly"]
# ...                                                   ...
# 835508                                                NaN
# 835509                                                NaN
# 835510                                                NaN
# 835511                                                NaN
# 835512                                                NaN
#
# [835513 rows x 6 columns]

# %%
#unir los 3 dataframe en uno solo

# %%
moviesandtitles = pd.merge(left=movies,right=titles, left_on='imdb_title_id', right_on='imdb_title_id')
moviesandtitles
# Out:
#        imdb_title_id                        title  \
# 0          tt0000009                   Miss Jerry
# 1          tt0000009                   Miss Jerry
# 2          tt0000009                   Miss Jerry
# 3          tt0000009                   Miss Jerry
# 4          tt0000574  The Story of the Kelly Gang
# ...              ...                          ...
# 835489     tt9914942   La vida sense la Sara Amat
# 835490     tt9914942   La vida sense la Sara Amat
# 835491     tt9914942   La vida sense la Sara Amat
# 835492     tt9914942   La vida sense la Sara Amat
# 835493     tt9914942   La vida sense la Sara Amat
#
#                      original_title  year date_published  \
# 0                        Miss Jerry  1894     1894-10-09
# 1                        Miss Jerry  1894     1894-10-09
# 2                        Miss Jerry  1894     1894-10-09
# 3                        Miss Jerry  1894     1894-10-09
# 4       The Story of the Kelly Gang  1906     1906-12-26
# ...                             ...   ...            ...
# 835489   La vida sense la Sara Amat  2019     2020-02-05
# 835490   La vida sense la Sara Amat  2019     2020-02-05
# 835491   La vida sense la Sara Amat  2019     2020-02-05
# 835492   La vida sense la Sara Amat  2019     2020-02-05
# 835493   La vida sense la Sara Amat  2019     2020-02-05
#
#                           genre  duration    country language  \
# 0                       Romance        45        USA     None
# 1                       Romance        45        USA     None
# 2                       Romance        45        USA     None
# 3                       Romance        45        USA     None
# 4       Biography, Crime, Drama        70  Australia     None
# ...                         ...       ...        ...      ...
# 835489                    Drama        74      Spain  Catalan
# 835490                    Drama        74      Spain  Catalan
# 835491                    Drama        74      Spain  Catalan
# 835492                    Drama        74      Spain  Catalan
# 835493                    Drama        74      Spain  Catalan
#
#                director  ... usa_gross_income worlwide_gross_income metascore  \
# 0       Alexander Black  ...              NaN                   NaN       NaN
# 1       Alexander Black  ...              NaN                   NaN       NaN
# 2       Alexander Black  ...              NaN                   NaN       NaN
# 3       Alexander Black  ...              NaN                   NaN       NaN
# 4          Charles Tait  ...              NaN                   NaN       NaN
# ...                 ...  ...              ...                   ...       ...
# 835489        Laura Jou  ...              NaN               $ 59794       NaN
# 835490        Laura Jou  ...              NaN               $ 59794       NaN
# 835491        Laura Jou  ...              NaN               $ 59794       NaN
# 835492        Laura Jou  ...              NaN               $ 59794       NaN
# 835493        Laura Jou  ...              NaN               $ 59794       NaN
#
#        reviews_from_users  reviews_from_critics  ordering imdb_name_id  \
# 0                     1.0                   2.0         1    nm0063086
# 1                     1.0                   2.0         2    nm0183823
# 2                     1.0                   2.0         3    nm1309758
# 3                     1.0                   2.0         4    nm0085156
# 4                     7.0                   7.0         1    nm0846887
# ...                   ...                   ...       ...          ...
# 835489                NaN                   2.0         6    nm3678448
# 835490                NaN                   2.0         7    nm9361716
# 835491                NaN                   2.0         8    nm2262072
# 835492                NaN                   2.0         9    nm1966322
# 835493                NaN                   2.0        10    nm0739828
#
#                category    job  \
# 0               actress    NaN
# 1                 actor    NaN
# 2                 actor    NaN
# 3              director    NaN
# 4               actress    NaN
# ...                 ...    ...
# 835489           writer    NaN
# 835490           writer  novel
# 835491         composer    NaN
# 835492  cinematographer    NaN
# 835493           editor    NaN
#
#                                                characters
# 0                ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                        ["Mr. Hamilton"]
# 2       ["Chauncey Depew - the Director of the New Yor...
# 3                                                     NaN
# 4                                          ["Kate Kelly"]
# ...                                                   ...
# 835489                                                NaN
# 835490                                                NaN
# 835491                                                NaN
# 835492                                                NaN
# 835493                                                NaN
#
# [835494 rows x 27 columns]

# %%
Peliculas = moviesandtitles = pd.merge(left=moviesandtitles,right=ratings, left_on='imdb_title_id', right_on='imdb_title_id')
Peliculas
# Out:
#        imdb_title_id                        title  \
# 0          tt0000009                   Miss Jerry
# 1          tt0000009                   Miss Jerry
# 2          tt0000009                   Miss Jerry
# 3          tt0000009                   Miss Jerry
# 4          tt0000574  The Story of the Kelly Gang
# ...              ...                          ...
# 835489     tt9914942   La vida sense la Sara Amat
# 835490     tt9914942   La vida sense la Sara Amat
# 835491     tt9914942   La vida sense la Sara Amat
# 835492     tt9914942   La vida sense la Sara Amat
# 835493     tt9914942   La vida sense la Sara Amat
#
#                      original_title  year date_published  \
# 0                        Miss Jerry  1894     1894-10-09
# 1                        Miss Jerry  1894     1894-10-09
# 2                        Miss Jerry  1894     1894-10-09
# 3                        Miss Jerry  1894     1894-10-09
# 4       The Story of the Kelly Gang  1906     1906-12-26
# ...                             ...   ...            ...
# 835489   La vida sense la Sara Amat  2019     2020-02-05
# 835490   La vida sense la Sara Amat  2019     2020-02-05
# 835491   La vida sense la Sara Amat  2019     2020-02-05
# 835492   La vida sense la Sara Amat  2019     2020-02-05
# 835493   La vida sense la Sara Amat  2019     2020-02-05
#
#                           genre  duration    country language  \
# 0                       Romance        45        USA     None
# 1                       Romance        45        USA     None
# 2                       Romance        45        USA     None
# 3                       Romance        45        USA     None
# 4       Biography, Crime, Drama        70  Australia     None
# ...                         ...       ...        ...      ...
# 835489                    Drama        74      Spain  Catalan
# 835490                    Drama        74      Spain  Catalan
# 835491                    Drama        74      Spain  Catalan
# 835492                    Drama        74      Spain  Catalan
# 835493                    Drama        74      Spain  Catalan
#
#                director  ... females_30age_avg_vote females_30age_votes  \
# 0       Alexander Black  ...                    5.7                13.0
# 1       Alexander Black  ...                    5.7                13.0
# 2       Alexander Black  ...                    5.7                13.0
# 3       Alexander Black  ...                    5.7                13.0
# 4          Charles Tait  ...                    6.2                23.0
# ...                 ...  ...                    ...                 ...
# 835489        Laura Jou  ...                    6.8                 4.0
# 835490        Laura Jou  ...                    6.8                 4.0
# 835491        Laura Jou  ...                    6.8                 4.0
# 835492        Laura Jou  ...                    6.8                 4.0
# 835493        Laura Jou  ...                    6.8                 4.0
#
#        females_45age_avg_vote females_45age_votes  top1000_voters_rating  \
# 0                         4.5                 4.0                    5.7
# 1                         4.5                 4.0                    5.7
# 2                         4.5                 4.0                    5.7
# 3                         4.5                 4.0                    5.7
# 4                         6.6                14.0                    6.4
# ...                       ...                 ...                    ...
# 835489                    7.5                 4.0                    7.0
# 835490                    7.5                 4.0                    7.0
# 835491                    7.5                 4.0                    7.0
# 835492                    7.5                 4.0                    7.0
# 835493                    7.5                 4.0                    7.0
#
#         top1000_voters_votes us_voters_rating us_voters_votes  \
# 0                       34.0              6.4            51.0
# 1                       34.0              6.4            51.0
# 2                       34.0              6.4            51.0
# 3                       34.0              6.4            51.0
# 4                       66.0              6.0            96.0
# ...                      ...              ...             ...
# 835489                   4.0              6.7            13.0
# 835490                   4.0              6.7            13.0
# 835491                   4.0              6.7            13.0
# 835492                   4.0              6.7            13.0
# 835493                   4.0              6.7            13.0
#
#        non_us_voters_rating  non_us_voters_votes
# 0                       6.0                 70.0
# 1                       6.0                 70.0
# 2                       6.0                 70.0
# 3                       6.0                 70.0
# 4                       6.2                331.0
# ...                     ...                  ...
# 835489                  6.7                 60.0
# 835490                  6.7                 60.0
# 835491                  6.7                 60.0
# 835492                  6.7                 60.0
# 835493                  6.7                 60.0
#
# [835494 rows x 75 columns]

# %%
#eliminar datos duplicados del dataframe

# %%
Peliculas.drop_duplicates('imdb_title_id')
# Out:
#        imdb_title_id                           title  \
# 0          tt0000009                      Miss Jerry
# 4          tt0000574     The Story of the Kelly Gang
# 14         tt0001892                  Den sorte drøm
# 24         tt0002101                       Cleopatra
# 34         tt0002130                       L'Inferno
# ...              ...                             ...
# 835445     tt9908390                         Le lion
# 835455     tt9911196  De Beentjes van Sint-Hildegard
# 835465     tt9911774       Padmavyuhathile Abhimanyu
# 835475     tt9914286               Sokagin Çocuklari
# 835484     tt9914942      La vida sense la Sara Amat
#
#                         original_title  year date_published  \
# 0                           Miss Jerry  1894     1894-10-09
# 4          The Story of the Kelly Gang  1906     1906-12-26
# 14                      Den sorte drøm  1911     1911-08-19
# 24                           Cleopatra  1912     1912-11-13
# 34                           L'Inferno  1911     1911-03-06
# ...                                ...   ...            ...
# 835445                         Le lion  2020     2020-01-29
# 835455  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 835465       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 835475               Sokagin Çocuklari  2019     2019-03-15
# 835484      La vida sense la Sara Amat  2019     2020-02-05
#
#                             genre  duration           country       language  \
# 0                         Romance        45               USA           None
# 4         Biography, Crime, Drama        70         Australia           None
# 14                          Drama        53  Germany, Denmark            NaN
# 24                 Drama, History       100               USA        English
# 34      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                           ...       ...               ...            ...
# 835445                     Comedy        95   France, Belgium         French
# 835455              Comedy, Drama       103       Netherlands  German, Dutch
# 835465                      Drama       130             India      Malayalam
# 835475              Drama, Family        98            Turkey        Turkish
# 835484                      Drama        74             Spain        Catalan
#
#                                    director  ... females_30age_avg_vote  \
# 0                           Alexander Black  ...                    5.7
# 4                              Charles Tait  ...                    6.2
# 14                                Urban Gad  ...                    5.8
# 24                       Charles L. Gaskill  ...                    5.5
# 34      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                     ...  ...                    ...
# 835445               Ludovic Colbeau-Justin  ...                    5.7
# 835455                      Johan Nijenhuis  ...                    8.0
# 835465                      Vineesh Aaradya  ...                    NaN
# 835475                    Ahmet Faik Akinci  ...                    NaN
# 835484                            Laura Jou  ...                    6.8
#
#        females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                     13.0                    4.5                 4.0
# 4                     23.0                    6.6                14.0
# 14                     4.0                    6.8                 7.0
# 24                    14.0                    6.1                21.0
# 34                    82.0                    7.4                77.0
# ...                    ...                    ...                 ...
# 835445                11.0                    5.0                 2.0
# 835455                47.0                    7.3                30.0
# 835465                 NaN                    NaN                 NaN
# 835475                 NaN                    7.0                 1.0
# 835484                 4.0                    7.5                 4.0
#
#         top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                         5.7                  34.0              6.4
# 4                         6.4                  66.0              6.0
# 14                        5.4                  32.0              6.2
# 24                        4.9                  57.0              5.5
# 34                        6.9                 139.0              7.0
# ...                       ...                   ...              ...
# 835445                    5.5                  12.0              6.3
# 835455                    7.0                   6.0              6.8
# 835465                    1.0                   1.0              NaN
# 835475                    4.0                   3.0              1.7
# 835484                    7.0                   4.0              6.7
#
#        us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                 51.0                  6.0                 70.0
# 4                 96.0                  6.2                331.0
# 14                31.0                  5.9                123.0
# 24               207.0                  4.7                105.0
# 34               488.0                  7.0               1166.0
# ...                ...                  ...                  ...
# 835445            22.0                  5.3                214.0
# 835455            13.0                  7.7                388.0
# 835465             NaN                  2.0                  2.0
# 835475             5.0                  5.8                  5.0
# 835484            13.0                  6.7                 60.0
#
# [85846 rows x 75 columns]

# %%
Peliculas.sort_values('title', inplace=True)
Peliculas
# Out:
#        imdb_title_id     title original_title  year date_published  \
# 167628     tt0073045  "Giliap"       "Giliap"  1975     1975-11-16
# 167631     tt0073045  "Giliap"       "Giliap"  1975     1975-11-16
# 167630     tt0073045  "Giliap"       "Giliap"  1975     1975-11-16
# 167629     tt0073045  "Giliap"       "Giliap"  1975     1975-11-16
# 167627     tt0073045  "Giliap"       "Giliap"  1975     1975-11-16
# ...              ...       ...            ...   ...            ...
# 697690     tt3509772    ärtico         ärtico  2014     2015-11-11
# 697689     tt3509772    ärtico         ärtico  2014     2015-11-11
# 697688     tt3509772    ärtico         ärtico  2014     2015-11-11
# 697686     tt3509772    ärtico         ärtico  2014     2015-11-11
# 697687     tt3509772    ärtico         ärtico  2014     2015-11-11
#
#                genre  duration country language           director  ...  \
# 167628  Crime, Drama       137  Sweden  Swedish      Roy Andersson  ...
# 167631  Crime, Drama       137  Sweden  Swedish      Roy Andersson  ...
# 167630  Crime, Drama       137  Sweden  Swedish      Roy Andersson  ...
# 167629  Crime, Drama       137  Sweden  Swedish      Roy Andersson  ...
# 167627  Crime, Drama       137  Sweden  Swedish      Roy Andersson  ...
# ...              ...       ...     ...      ...                ...  ...
# 697690         Drama        78   Spain  Spanish  Gabriel Velázquez  ...
# 697689         Drama        78   Spain  Spanish  Gabriel Velázquez  ...
# 697688         Drama        78   Spain  Spanish  Gabriel Velázquez  ...
# 697686         Drama        78   Spain  Spanish  Gabriel Velázquez  ...
# 697687         Drama        78   Spain  Spanish  Gabriel Velázquez  ...
#
#        females_30age_avg_vote females_30age_votes females_45age_avg_vote  \
# 167628                    6.0                40.0                    6.7
# 167631                    6.0                40.0                    6.7
# 167630                    6.0                40.0                    6.7
# 167629                    6.0                40.0                    6.7
# 167627                    6.0                40.0                    6.7
# ...                       ...                 ...                    ...
# 697690                    7.1                16.0                    6.2
# 697689                    7.1                16.0                    6.2
# 697688                    7.1                16.0                    6.2
# 697686                    7.1                16.0                    6.2
# 697687                    7.1                16.0                    6.2
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 167628                14.0                    5.7                  35.0
# 167631                14.0                    5.7                  35.0
# 167630                14.0                    5.7                  35.0
# 167629                14.0                    5.7                  35.0
# 167627                14.0                    5.7                  35.0
# ...                    ...                    ...                   ...
# 697690                 9.0                    5.0                   1.0
# 697689                 9.0                    5.0                   1.0
# 697688                 9.0                    5.0                   1.0
# 697686                 9.0                    5.0                   1.0
# 697687                 9.0                    5.0                   1.0
#
#        us_voters_rating us_voters_votes non_us_voters_rating  \
# 167628              6.9            64.0                  6.4
# 167631              6.9            64.0                  6.4
# 167630              6.9            64.0                  6.4
# 167629              6.9            64.0                  6.4
# 167627              6.9            64.0                  6.4
# ...                 ...             ...                  ...
# 697690              5.3             3.0                  5.8
# 697689              5.3             3.0                  5.8
# 697688              5.3             3.0                  5.8
# 697686              5.3             3.0                  5.8
# 697687              5.3             3.0                  5.8
#
#         non_us_voters_votes
# 167628                496.0
# 167631                496.0
# 167630                496.0
# 167629                496.0
# 167627                496.0
# ...                     ...
# 697690                 50.0
# 697689                 50.0
# 697688                 50.0
# 697686                 50.0
# 697687                 50.0
#
# [835494 rows x 75 columns]

# %%
Peliculas.drop_duplicates('imdb_title_id', keep="last", inplace=True)
Peliculas.sort_index(inplace=True)

# %%
Peliculas
# Out:
#        imdb_title_id                           title  \
# 3          tt0000009                      Miss Jerry
# 11         tt0000574     The Story of the Kelly Gang
# 20         tt0001892                  Den sorte drøm
# 24         tt0002101                       Cleopatra
# 36         tt0002130                       L'Inferno
# ...              ...                             ...
# 835454     tt9908390                         Le lion
# 835460     tt9911196  De Beentjes van Sint-Hildegard
# 835473     tt9911774       Padmavyuhathile Abhimanyu
# 835481     tt9914286               Sokagin Çocuklari
# 835492     tt9914942      La vida sense la Sara Amat
#
#                         original_title  year date_published  \
# 3                           Miss Jerry  1894     1894-10-09
# 11         The Story of the Kelly Gang  1906     1906-12-26
# 20                      Den sorte drøm  1911     1911-08-19
# 24                           Cleopatra  1912     1912-11-13
# 36                           L'Inferno  1911     1911-03-06
# ...                                ...   ...            ...
# 835454                         Le lion  2020     2020-01-29
# 835460  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 835473       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 835481               Sokagin Çocuklari  2019     2019-03-15
# 835492      La vida sense la Sara Amat  2019     2020-02-05
#
#                             genre  duration           country       language  \
# 3                         Romance        45               USA           None
# 11        Biography, Crime, Drama        70         Australia           None
# 20                          Drama        53  Germany, Denmark            NaN
# 24                 Drama, History       100               USA        English
# 36      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                           ...       ...               ...            ...
# 835454                     Comedy        95   France, Belgium         French
# 835460              Comedy, Drama       103       Netherlands  German, Dutch
# 835473                      Drama       130             India      Malayalam
# 835481              Drama, Family        98            Turkey        Turkish
# 835492                      Drama        74             Spain        Catalan
#
#                                    director  ... females_30age_avg_vote  \
# 3                           Alexander Black  ...                    5.7
# 11                             Charles Tait  ...                    6.2
# 20                                Urban Gad  ...                    5.8
# 24                       Charles L. Gaskill  ...                    5.5
# 36      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                     ...  ...                    ...
# 835454               Ludovic Colbeau-Justin  ...                    5.7
# 835460                      Johan Nijenhuis  ...                    8.0
# 835473                      Vineesh Aaradya  ...                    NaN
# 835481                    Ahmet Faik Akinci  ...                    NaN
# 835492                            Laura Jou  ...                    6.8
#
#        females_30age_votes females_45age_avg_vote females_45age_votes  \
# 3                     13.0                    4.5                 4.0
# 11                    23.0                    6.6                14.0
# 20                     4.0                    6.8                 7.0
# 24                    14.0                    6.1                21.0
# 36                    82.0                    7.4                77.0
# ...                    ...                    ...                 ...
# 835454                11.0                    5.0                 2.0
# 835460                47.0                    7.3                30.0
# 835473                 NaN                    NaN                 NaN
# 835481                 NaN                    7.0                 1.0
# 835492                 4.0                    7.5                 4.0
#
#         top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 3                         5.7                  34.0              6.4
# 11                        6.4                  66.0              6.0
# 20                        5.4                  32.0              6.2
# 24                        4.9                  57.0              5.5
# 36                        6.9                 139.0              7.0
# ...                       ...                   ...              ...
# 835454                    5.5                  12.0              6.3
# 835460                    7.0                   6.0              6.8
# 835473                    1.0                   1.0              NaN
# 835481                    4.0                   3.0              1.7
# 835492                    7.0                   4.0              6.7
#
#        us_voters_votes non_us_voters_rating  non_us_voters_votes
# 3                 51.0                  6.0                 70.0
# 11                96.0                  6.2                331.0
# 20                31.0                  5.9                123.0
# 24               207.0                  4.7                105.0
# 36               488.0                  7.0               1166.0
# ...                ...                  ...                  ...
# 835454            22.0                  5.3                214.0
# 835460            13.0                  7.7                388.0
# 835473             NaN                  2.0                  2.0
# 835481             5.0                  5.8                  5.0
# 835492            13.0                  6.7                 60.0
#
# [85846 rows x 75 columns]

# %%
#elimino la columna Imdb_tittle_id
Peliculas = Peliculas.drop(['imdb_title_id'], axis=1)

# %%
Peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85846 entries, 3 to 835492
# Data columns (total 74 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      85846 non-null  object
#  1   original_title             85846 non-null  object
#  2   year                       85846 non-null  object
#  3   date_published             85846 non-null  object
#  4   genre                      85846 non-null  object
#  5   duration                   85846 non-null  int64
#  6   country                    85785 non-null  object
#  7   language                   85018 non-null  object
#  8   director                   85768 non-null  object
#  9   writer                     84283 non-null  object
#  10  production_company         81397 non-null  object
#  11  actors                     85786 non-null  object
#  12  description                83731 non-null  object
#  13  avg_vote                   85846 non-null  float64
#  14  votes                      85846 non-null  int64
#  15  budget                     23709 non-null  object
#  16  usa_gross_income           15325 non-null  object
#  17  worlwide_gross_income      31015 non-null  object
#  18  metascore                  13305 non-null  float64
#  19  reviews_from_users         78251 non-null  float64
#  20  reviews_from_critics       74057 non-null  float64
#  21  ordering                   85846 non-null  int64
#  22  imdb_name_id               85846 non-null  object
#  23  category                   85846 non-null  object
#  24  job                        20596 non-null  object
#  25  characters                 35942 non-null  object
#  26  weighted_average_vote      85846 non-null  float64
#  27  total_votes                85846 non-null  int64
#  28  mean_vote                  85846 non-null  float64
#  29  median_vote                85846 non-null  float64
#  30  votes_10                   85846 non-null  int64
#  31  votes_9                    85846 non-null  int64
#  32  votes_8                    85846 non-null  int64
#  33  votes_7                    85846 non-null  int64
#  34  votes_6                    85846 non-null  int64
#  35  votes_5                    85846 non-null  int64
#  36  votes_4                    85846 non-null  int64
#  37  votes_3                    85846 non-null  int64
#  38  votes_2                    85846 non-null  int64
#  39  votes_1                    85846 non-null  int64
#  40  allgenders_0age_avg_vote   33358 non-null  float64
#  41  allgenders_0age_votes      33358 non-null  float64
#  42  allgenders_18age_avg_vote  85140 non-null  float64
#  43  allgenders_18age_votes     85140 non-null  float64
#  44  allgenders_30age_avg_vote  85836 non-null  float64
#  45  allgenders_30age_votes     85836 non-null  float64
#  46  allgenders_45age_avg_vote  85766 non-null  float64
#  47  allgenders_45age_votes     85766 non-null  float64
#  48  males_allages_avg_vote     85845 non-null  float64
#  49  males_allages_votes        85845 non-null  float64
#  50  males_0age_avg_vote        27410 non-null  float64
#  51  males_0age_votes           27410 non-null  float64
#  52  males_18age_avg_vote       84381 non-null  float64
#  53  males_18age_votes          84381 non-null  float64
#  54  males_30age_avg_vote       85834 non-null  float64
#  55  males_30age_votes          85834 non-null  float64
#  56  males_45age_avg_vote       85745 non-null  float64
#  57  males_45age_votes          85745 non-null  float64
#  58  females_allages_avg_vote   85765 non-null  float64
#  59  females_allages_votes      85765 non-null  float64
#  60  females_0age_avg_vote      22117 non-null  float64
#  61  females_0age_votes         22117 non-null  float64
#  62  females_18age_avg_vote     79326 non-null  float64
#  63  females_18age_votes        79326 non-null  float64
#  64  females_30age_avg_vote     84902 non-null  float64
#  65  females_30age_votes        84902 non-null  float64
#  66  females_45age_avg_vote     83048 non-null  float64
#  67  females_45age_votes        83048 non-null  float64
#  68  top1000_voters_rating      85168 non-null  float64
#  69  top1000_voters_votes       85168 non-null  float64
#  70  us_voters_rating           85637 non-null  float64
#  71  us_voters_votes            85637 non-null  float64
#  72  non_us_voters_rating       85845 non-null  float64
#  73  non_us_voters_votes        85845 non-null  float64
# dtypes: float64(41), int64(14), object(19)
# memory usage: 49.1+ MB

# %%
Peliculas.drop(['original_title', 'date_published', 'imdb_name_id', 'category', 'job', 'characters', 'weighted_average_vote', 'total_votes', 'mean_vote', 'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6', 'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1', 'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating', 'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'], axis = 'columns', inplace=True)

# %%
Peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85846 entries, 3 to 835492
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      85846 non-null  object
#  1   year                       85846 non-null  object
#  2   genre                      85846 non-null  object
#  3   duration                   85846 non-null  int64
#  4   country                    85785 non-null  object
#  5   language                   85018 non-null  object
#  6   director                   85768 non-null  object
#  7   writer                     84283 non-null  object
#  8   production_company         81397 non-null  object
#  9   actors                     85786 non-null  object
#  10  description                83731 non-null  object
#  11  avg_vote                   85846 non-null  float64
#  12  votes                      85846 non-null  int64
#  13  budget                     23709 non-null  object
#  14  usa_gross_income           15325 non-null  object
#  15  worlwide_gross_income      31015 non-null  object
#  16  metascore                  13305 non-null  float64
#  17  reviews_from_users         78251 non-null  float64
#  18  reviews_from_critics       74057 non-null  float64
#  19  ordering                   85846 non-null  int64
#  20  allgenders_0age_avg_vote   33358 non-null  float64
#  21  allgenders_0age_votes      33358 non-null  float64
#  22  allgenders_18age_avg_vote  85140 non-null  float64
#  23  allgenders_18age_votes     85140 non-null  float64
#  24  allgenders_30age_avg_vote  85836 non-null  float64
#  25  allgenders_30age_votes     85836 non-null  float64
#  26  allgenders_45age_avg_vote  85766 non-null  float64
#  27  allgenders_45age_votes     85766 non-null  float64
#  28  males_allages_avg_vote     85845 non-null  float64
#  29  males_allages_votes        85845 non-null  float64
#  30  males_0age_avg_vote        27410 non-null  float64
#  31  males_0age_votes           27410 non-null  float64
#  32  males_18age_avg_vote       84381 non-null  float64
#  33  males_18age_votes          84381 non-null  float64
#  34  males_30age_avg_vote       85834 non-null  float64
#  35  males_30age_votes          85834 non-null  float64
#  36  males_45age_avg_vote       85745 non-null  float64
#  37  males_45age_votes          85745 non-null  float64
#  38  females_allages_avg_vote   85765 non-null  float64
#  39  females_allages_votes      85765 non-null  float64
#  40  females_0age_avg_vote      22117 non-null  float64
#  41  females_0age_votes         22117 non-null  float64
#  42  females_18age_avg_vote     79326 non-null  float64
#  43  females_18age_votes        79326 non-null  float64
#  44  females_30age_avg_vote     84902 non-null  float64
#  45  females_30age_votes        84902 non-null  float64
#  46  females_45age_avg_vote     83048 non-null  float64
#  47  females_45age_votes        83048 non-null  float64
# dtypes: float64(32), int64(3), object(13)
# memory usage: 32.1+ MB

# %%
Peliculas.drop(['ordering'], axis = 'columns', inplace=True)

# %%
Peliculas
# Out:
#                                  title  year                      genre  \
# 3                           Miss Jerry  1894                    Romance
# 11         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 20                      Den sorte drøm  1911                      Drama
# 24                           Cleopatra  1912             Drama, History
# 36                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                                ...   ...                        ...
# 835454                         Le lion  2020                     Comedy
# 835460  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 835473       Padmavyuhathile Abhimanyu  2019                      Drama
# 835481               Sokagin Çocuklari  2019              Drama, Family
# 835492      La vida sense la Sara Amat  2019                      Drama
#
#         duration           country       language  \
# 3             45               USA           None
# 11            70         Australia           None
# 20            53  Germany, Denmark            NaN
# 24           100               USA        English
# 36            68             Italy        Italian
# ...          ...               ...            ...
# 835454        95   France, Belgium         French
# 835460       103       Netherlands  German, Dutch
# 835473       130             India      Malayalam
# 835481        98            Turkey        Turkish
# 835492        74             Spain        Catalan
#
#                                    director  \
# 3                           Alexander Black
# 11                             Charles Tait
# 20                                Urban Gad
# 24                       Charles L. Gaskill
# 36      Francesco Bertolini, Adolfo Padovan
# ...                                     ...
# 835454               Ludovic Colbeau-Justin
# 835460                      Johan Nijenhuis
# 835473                      Vineesh Aaradya
# 835481                    Ahmet Faik Akinci
# 835492                            Laura Jou
#
#                                        writer             production_company  \
# 3                             Alexander Black     Alexander Black Photoplays
# 11                               Charles Tait                 J. and N. Tait
# 20      Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 24                           Victorien Sardou  Helen Gardner Picture Players
# 36                            Dante Alighieri                    Milano Film
# ...                                       ...                            ...
# 835454  Alexandre Coquelle, Matthieu Le Naour              Monkey Pack Films
# 835460           Radek Bajgar, Herman Finkers           Johan Nijenhuis & Co
# 835473       Vineesh Aaradya, Vineesh Aaradya               RMCC Productions
# 835481         Ahmet Faik Akinci, Kasim Uçkan                    Gizem Ajans
# 835492                   Coral Cruz, Pep Puig  La Xarxa de Comunicació Local
#
#                                                    actors  ...  \
# 3       Blanche Bayliss, William Courtenay, Chauncey D...  ...
# 11      Elizabeth Tait, John Tait, Norman Campbell, Be...  ...
# 20      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  ...
# 24      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  ...
# 36      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  ...
# ...                                                   ...  ...
# 835454  Dany Boon, Philippe Katerine, Anne Serra, Samu...  ...
# 835460  Herman Finkers, Johanna ter Steege, Leonie ter...  ...
# 835473  Anoop Chandran, Indrans, Sona Nair, Simon Brit...  ...
# 835481  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...  ...
# 835492  Maria Morera Colomer, Biel Rossell Pelfort, Is...  ...
#
#        females_allages_avg_vote  females_allages_votes  females_0age_avg_vote  \
# 3                           6.0                   35.0                    7.3
# 11                          6.2                   50.0                    NaN
# 20                          5.7                   15.0                    NaN
# 24                          5.9                   39.0                    NaN
# 36                          7.2                  215.0                    7.0
# ...                         ...                    ...                    ...
# 835454                      6.0                   26.0                    NaN
# 835460                      7.6                  109.0                    NaN
# 835473                      NaN                    NaN                    NaN
# 835481                      4.0                    2.0                    NaN
# 835492                      6.9                   15.0                    NaN
#
#        females_0age_votes females_18age_avg_vote females_18age_votes  \
# 3                     3.0                    5.9                14.0
# 11                    NaN                    5.9                12.0
# 20                    NaN                    5.8                 4.0
# 24                    NaN                    5.7                 3.0
# 36                    2.0                    7.0                52.0
# ...                   ...                    ...                 ...
# 835454                NaN                    6.2                11.0
# 835460                NaN                    7.4                29.0
# 835473                NaN                    NaN                 NaN
# 835481                NaN                    NaN                 NaN
# 835492                NaN                    6.7                 6.0
#
#         females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 3                          5.7                 13.0                     4.5
# 11                         6.2                 23.0                     6.6
# 20                         5.8                  4.0                     6.8
# 24                         5.5                 14.0                     6.1
# 36                         7.3                 82.0                     7.4
# ...                        ...                  ...                     ...
# 835454                     5.7                 11.0                     5.0
# 835460                     8.0                 47.0                     7.3
# 835473                     NaN                  NaN                     NaN
# 835481                     NaN                  NaN                     7.0
# 835492                     6.8                  4.0                     7.5
#
#         females_45age_votes
# 3                       4.0
# 11                     14.0
# 20                      7.0
# 24                     21.0
# 36                     77.0
# ...                     ...
# 835454                  2.0
# 835460                 30.0
# 835473                  NaN
# 835481                  1.0
# 835492                  4.0
#
# [85846 rows x 47 columns]

# %%
Peliculas.reset_index(level=0, inplace=True)

# %%
Peliculas.drop(['index'], axis = 'columns', inplace=True)

# %%
Peliculas
# Out:
#                                 title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85841                         Le lion  2020                     Comedy
# 85842  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85843       Padmavyuhathile Abhimanyu  2019                      Drama
# 85844               Sokagin Çocuklari  2019              Drama, Family
# 85845      La vida sense la Sara Amat  2019                      Drama
#
#        duration           country       language  \
# 0            45               USA           None
# 1            70         Australia           None
# 2            53  Germany, Denmark            NaN
# 3           100               USA        English
# 4            68             Italy        Italian
# ...         ...               ...            ...
# 85841        95   France, Belgium         French
# 85842       103       Netherlands  German, Dutch
# 85843       130             India      Malayalam
# 85844        98            Turkey        Turkish
# 85845        74             Spain        Catalan
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85841               Ludovic Colbeau-Justin
# 85842                      Johan Nijenhuis
# 85843                      Vineesh Aaradya
# 85844                    Ahmet Faik Akinci
# 85845                            Laura Jou
#
#                                       writer             production_company  \
# 0                            Alexander Black     Alexander Black Photoplays
# 1                               Charles Tait                 J. and N. Tait
# 2      Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                           Victorien Sardou  Helen Gardner Picture Players
# 4                            Dante Alighieri                    Milano Film
# ...                                      ...                            ...
# 85841  Alexandre Coquelle, Matthieu Le Naour              Monkey Pack Films
# 85842           Radek Bajgar, Herman Finkers           Johan Nijenhuis & Co
# 85843       Vineesh Aaradya, Vineesh Aaradya               RMCC Productions
# 85844         Ahmet Faik Akinci, Kasim Uçkan                    Gizem Ajans
# 85845                   Coral Cruz, Pep Puig  La Xarxa de Comunicació Local
#
#                                                   actors  ...  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  ...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  ...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  ...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  ...
# ...                                                  ...  ...
# 85841  Dany Boon, Philippe Katerine, Anne Serra, Samu...  ...
# 85842  Herman Finkers, Johanna ter Steege, Leonie ter...  ...
# 85843  Anoop Chandran, Indrans, Sona Nair, Simon Brit...  ...
# 85844  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...  ...
# 85845  Maria Morera Colomer, Biel Rossell Pelfort, Is...  ...
#
#       females_allages_avg_vote  females_allages_votes  females_0age_avg_vote  \
# 0                          6.0                   35.0                    7.3
# 1                          6.2                   50.0                    NaN
# 2                          5.7                   15.0                    NaN
# 3                          5.9                   39.0                    NaN
# 4                          7.2                  215.0                    7.0
# ...                        ...                    ...                    ...
# 85841                      6.0                   26.0                    NaN
# 85842                      7.6                  109.0                    NaN
# 85843                      NaN                    NaN                    NaN
# 85844                      4.0                    2.0                    NaN
# 85845                      6.9                   15.0                    NaN
#
#       females_0age_votes females_18age_avg_vote females_18age_votes  \
# 0                    3.0                    5.9                14.0
# 1                    NaN                    5.9                12.0
# 2                    NaN                    5.8                 4.0
# 3                    NaN                    5.7                 3.0
# 4                    2.0                    7.0                52.0
# ...                  ...                    ...                 ...
# 85841                NaN                    6.2                11.0
# 85842                NaN                    7.4                29.0
# 85843                NaN                    NaN                 NaN
# 85844                NaN                    NaN                 NaN
# 85845                NaN                    6.7                 6.0
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         5.7                 13.0                     4.5
# 1                         6.2                 23.0                     6.6
# 2                         5.8                  4.0                     6.8
# 3                         5.5                 14.0                     6.1
# 4                         7.3                 82.0                     7.4
# ...                       ...                  ...                     ...
# 85841                     5.7                 11.0                     5.0
# 85842                     8.0                 47.0                     7.3
# 85843                     NaN                  NaN                     NaN
# 85844                     NaN                  NaN                     7.0
# 85845                     6.8                  4.0                     7.5
#
#        females_45age_votes
# 0                      4.0
# 1                     14.0
# 2                      7.0
# 3                     21.0
# 4                     77.0
# ...                    ...
# 85841                  2.0
# 85842                 30.0
# 85843                  NaN
# 85844                  1.0
# 85845                  4.0
#
# [85846 rows x 47 columns]

# %%
Peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85846 entries, 0 to 85845
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      85846 non-null  object
#  1   year                       85846 non-null  object
#  2   genre                      85846 non-null  object
#  3   duration                   85846 non-null  int64
#  4   country                    85785 non-null  object
#  5   language                   85018 non-null  object
#  6   director                   85768 non-null  object
#  7   writer                     84283 non-null  object
#  8   production_company         81397 non-null  object
#  9   actors                     85786 non-null  object
#  10  description                83731 non-null  object
#  11  avg_vote                   85846 non-null  float64
#  12  votes                      85846 non-null  int64
#  13  budget                     23709 non-null  object
#  14  usa_gross_income           15325 non-null  object
#  15  worlwide_gross_income      31015 non-null  object
#  16  metascore                  13305 non-null  float64
#  17  reviews_from_users         78251 non-null  float64
#  18  reviews_from_critics       74057 non-null  float64
#  19  allgenders_0age_avg_vote   33358 non-null  float64
#  20  allgenders_0age_votes      33358 non-null  float64
#  21  allgenders_18age_avg_vote  85140 non-null  float64
#  22  allgenders_18age_votes     85140 non-null  float64
#  23  allgenders_30age_avg_vote  85836 non-null  float64
#  24  allgenders_30age_votes     85836 non-null  float64
#  25  allgenders_45age_avg_vote  85766 non-null  float64
#  26  allgenders_45age_votes     85766 non-null  float64
#  27  males_allages_avg_vote     85845 non-null  float64
#  28  males_allages_votes        85845 non-null  float64
#  29  males_0age_avg_vote        27410 non-null  float64
#  30  males_0age_votes           27410 non-null  float64
#  31  males_18age_avg_vote       84381 non-null  float64
#  32  males_18age_votes          84381 non-null  float64
#  33  males_30age_avg_vote       85834 non-null  float64
#  34  males_30age_votes          85834 non-null  float64
#  35  males_45age_avg_vote       85745 non-null  float64
#  36  males_45age_votes          85745 non-null  float64
#  37  females_allages_avg_vote   85765 non-null  float64
#  38  females_allages_votes      85765 non-null  float64
#  39  females_0age_avg_vote      22117 non-null  float64
#  40  females_0age_votes         22117 non-null  float64
#  41  females_18age_avg_vote     79326 non-null  float64
#  42  females_18age_votes        79326 non-null  float64
#  43  females_30age_avg_vote     84902 non-null  float64
#  44  females_30age_votes        84902 non-null  float64
#  45  females_45age_avg_vote     83048 non-null  float64
#  46  females_45age_votes        83048 non-null  float64
# dtypes: float64(32), int64(2), object(13)
# memory usage: 30.8+ MB

# %%
Peliculas.drop(['allgenders_0age_votes','allgenders_18age_votes','allgenders_30age_votes','allgenders_45age_votes'], axis = 'columns', inplace=True)

# %%
Peliculas.drop(['males_allages_votes','males_0age_votes','males_18age_votes','males_30age_votes','males_45age_votes'], axis = 'columns', inplace=True)

# %%
Peliculas.drop(['females_allages_votes','females_0age_votes','females_18age_votes','females_30age_votes','females_45age_votes'], axis = 'columns', inplace=True)

# %%
Peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85846 entries, 0 to 85845
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      85846 non-null  object
#  1   year                       85846 non-null  object
#  2   genre                      85846 non-null  object
#  3   duration                   85846 non-null  int64
#  4   country                    85785 non-null  object
#  5   language                   85018 non-null  object
#  6   director                   85768 non-null  object
#  7   writer                     84283 non-null  object
#  8   production_company         81397 non-null  object
#  9   actors                     85786 non-null  object
#  10  description                83731 non-null  object
#  11  avg_vote                   85846 non-null  float64
#  12  votes                      85846 non-null  int64
#  13  budget                     23709 non-null  object
#  14  usa_gross_income           15325 non-null  object
#  15  worlwide_gross_income      31015 non-null  object
#  16  metascore                  13305 non-null  float64
#  17  reviews_from_users         78251 non-null  float64
#  18  reviews_from_critics       74057 non-null  float64
#  19  allgenders_0age_avg_vote   33358 non-null  float64
#  20  allgenders_18age_avg_vote  85140 non-null  float64
#  21  allgenders_30age_avg_vote  85836 non-null  float64
#  22  allgenders_45age_avg_vote  85766 non-null  float64
#  23  males_allages_avg_vote     85845 non-null  float64
#  24  males_0age_avg_vote        27410 non-null  float64
#  25  males_18age_avg_vote       84381 non-null  float64
#  26  males_30age_avg_vote       85834 non-null  float64
#  27  males_45age_avg_vote       85745 non-null  float64
#  28  females_allages_avg_vote   85765 non-null  float64
#  29  females_0age_avg_vote      22117 non-null  float64
#  30  females_18age_avg_vote     79326 non-null  float64
#  31  females_30age_avg_vote     84902 non-null  float64
#  32  females_45age_avg_vote     83048 non-null  float64
# dtypes: float64(18), int64(2), object(13)
# memory usage: 21.6+ MB

# %%
##DATAFRAME FINAL
Peliculas
# Out:
#                                 title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85841                         Le lion  2020                     Comedy
# 85842  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85843       Padmavyuhathile Abhimanyu  2019                      Drama
# 85844               Sokagin Çocuklari  2019              Drama, Family
# 85845      La vida sense la Sara Amat  2019                      Drama
#
#        duration           country       language  \
# 0            45               USA           None
# 1            70         Australia           None
# 2            53  Germany, Denmark            NaN
# 3           100               USA        English
# 4            68             Italy        Italian
# ...         ...               ...            ...
# 85841        95   France, Belgium         French
# 85842       103       Netherlands  German, Dutch
# 85843       130             India      Malayalam
# 85844        98            Turkey        Turkish
# 85845        74             Spain        Catalan
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85841               Ludovic Colbeau-Justin
# 85842                      Johan Nijenhuis
# 85843                      Vineesh Aaradya
# 85844                    Ahmet Faik Akinci
# 85845                            Laura Jou
#
#                                       writer             production_company  \
# 0                            Alexander Black     Alexander Black Photoplays
# 1                               Charles Tait                 J. and N. Tait
# 2      Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                           Victorien Sardou  Helen Gardner Picture Players
# 4                            Dante Alighieri                    Milano Film
# ...                                      ...                            ...
# 85841  Alexandre Coquelle, Matthieu Le Naour              Monkey Pack Films
# 85842           Radek Bajgar, Herman Finkers           Johan Nijenhuis & Co
# 85843       Vineesh Aaradya, Vineesh Aaradya               RMCC Productions
# 85844         Ahmet Faik Akinci, Kasim Uçkan                    Gizem Ajans
# 85845                   Coral Cruz, Pep Puig  La Xarxa de Comunicació Local
#
#                                                   actors  ...  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...  ...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...  ...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...  ...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...  ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...  ...
# ...                                                  ...  ...
# 85841  Dany Boon, Philippe Katerine, Anne Serra, Samu...  ...
# 85842  Herman Finkers, Johanna ter Steege, Leonie ter...  ...
# 85843  Anoop Chandran, Indrans, Sona Nair, Simon Brit...  ...
# 85844  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...  ...
# 85845  Maria Morera Colomer, Biel Rossell Pelfort, Is...  ...
#
#       males_allages_avg_vote  males_0age_avg_vote  males_18age_avg_vote  \
# 0                        6.2                  7.0                   5.9
# 1                        6.1                  6.0                   6.2
# 2                        5.9                  NaN                   5.5
# 3                        5.1                  NaN                   5.2
# 4                        7.0                  8.0                   7.0
# ...                      ...                  ...                   ...
# 85841                    5.3                  6.0                   5.6
# 85842                    7.8                  NaN                   7.6
# 85843                    6.0                  NaN                   1.0
# 85844                    3.1                  NaN                   6.5
# 85845                    6.6                  NaN                   6.8
#
#       males_30age_avg_vote males_45age_avg_vote females_allages_avg_vote  \
# 0                      5.6                  6.7                      6.0
# 1                      6.0                  6.2                      6.2
# 2                      5.9                  6.2                      5.7
# 3                      4.9                  5.2                      5.9
# 4                      7.0                  7.0                      7.2
# ...                    ...                  ...                      ...
# 85841                  5.3                  5.2                      6.0
# 85842                  7.6                  7.9                      7.6
# 85843                 10.0                  3.0                      NaN
# 85844                  1.8                  1.0                      4.0
# 85845                  6.4                  6.5                      6.9
#
#        females_0age_avg_vote  females_18age_avg_vote  females_30age_avg_vote  \
# 0                        7.3                     5.9                     5.7
# 1                        NaN                     5.9                     6.2
# 2                        NaN                     5.8                     5.8
# 3                        NaN                     5.7                     5.5
# 4                        7.0                     7.0                     7.3
# ...                      ...                     ...                     ...
# 85841                    NaN                     6.2                     5.7
# 85842                    NaN                     7.4                     8.0
# 85843                    NaN                     NaN                     NaN
# 85844                    NaN                     NaN                     NaN
# 85845                    NaN                     6.7                     6.8
#
#        females_45age_avg_vote
# 0                         4.5
# 1                         6.6
# 2                         6.8
# 3                         6.1
# 4                         7.4
# ...                       ...
# 85841                     5.0
# 85842                     7.3
# 85843                     NaN
# 85844                     7.0
# 85845                     7.5
#
# [85846 rows x 33 columns]

# %%
Peliculas.describe()
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85846.000000  85846.000000  8.584600e+04  13305.000000
# mean     100.350407      5.898579  9.494453e+03     55.896881
# std       22.550865      1.234853  5.357709e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.767000e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics  allgenders_0age_avg_vote  \
# count        78251.000000          74057.000000              33358.000000
# mean            46.044012             27.479874                  6.195051
# std            178.519029             58.339544                  1.849119
# min              1.000000              1.000000                  1.000000
# 25%              4.000000              3.000000                  5.000000
# 50%              9.000000              8.000000                  6.000000
# 75%             27.000000             23.000000                  7.200000
# max          10472.000000            999.000000                 10.000000
#
#        allgenders_18age_avg_vote  allgenders_30age_avg_vote  \
# count               85140.000000               85836.000000
# mean                    6.011241                   5.862828
# std                     1.439624                   1.279272
# min                     1.000000                   1.000000
# 25%                     5.300000                   5.100000
# 50%                     6.200000                   6.100000
# 75%                     7.000000                   6.800000
# max                    10.000000                  10.000000
#
#        allgenders_45age_avg_vote  males_allages_avg_vote  males_0age_avg_vote  \
# count               85766.000000            85845.000000         27410.000000
# mean                    5.678169                5.817099             6.221306
# std                     1.250527                1.247913             1.767543
# min                     1.000000                1.000000             1.000000
# 25%                     5.000000                5.100000             5.000000
# 50%                     5.900000                6.000000             6.000000
# 75%                     6.600000                6.700000             7.200000
# max                    10.000000               10.000000            10.000000
#
#        males_18age_avg_vote  males_30age_avg_vote  males_45age_avg_vote  \
# count          84381.000000          85834.000000          85745.000000
# mean               5.946301              5.817684              5.630131
# std                1.463981              1.289092              1.263938
# min                1.000000              1.000000              1.000000
# 25%                5.100000              5.100000              4.900000
# 50%                6.200000              6.000000              5.900000
# 75%                7.000000              6.700000              6.500000
# max               10.000000             10.000000             10.000000
#
#        females_allages_avg_vote  females_0age_avg_vote  \
# count              85765.000000           22117.000000
# mean                   6.039305               6.147308
# std                    1.346087               1.878342
# min                    1.000000               1.000000
# 25%                    5.300000               5.000000
# 50%                    6.300000               6.000000
# 75%                    7.000000               7.100000
# max                   10.000000              10.000000
#
#        females_18age_avg_vote  females_30age_avg_vote  females_45age_avg_vote
# count            79326.000000            84902.000000            83048.000000
# mean                 6.321438                6.071089                6.022184
# std                  1.738790                1.454205                1.541844
# min                  1.000000                1.000000                1.000000
# 25%                  5.500000                5.300000                5.200000
# 50%                  6.500000                6.300000                6.200000
# 75%                  7.400000                7.000000                7.000000
# max                 10.000000               10.000000               10.000000

# %% [raw]
# ¿Cuales son los generos más representativos? ¿Cual ha sido la evolución del contenido publicado?

# %%
def split_multicolumn(genres):
    result_df = genres.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in genres[genres.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(','):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
genres_df = split_multicolumn(Peliculas.genre)
movie_genres = genres_df.sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=movie_genres.values, y=movie_genres.index);

# %%
Peliculas.year.unique()
# Out:
# array(['1894', '1906', '1911', '1912', '1919', '1913', '1914', '1915',
#        '1916', '1917', '1918', '1920', '1921', '1924', '1922', '1923',
#        '1925', '1926', '1935', '1927', '1928', '1983', '1929', '1930',
#        '1932', '1931', '1937', '1938', '1933', '1934', '1936', '1940',
#        '1939', '1942', '1943', '1941', '1948', '1944', '2001', '1946',
#        '1945', '1947', '1973', '1949', '1950', '1952', '1951', '1962',
#        '1953', '1954', '1955', '1961', '1956', '1958', '1957', '1959',
#        '1960', '1963', '1965', '1971', '1964', '1966', '1968', '1967',
#        '1969', '1976', '1970', '1979', '1972', '1981', '1978', '2000',
#        '1989', '1975', '1974', '1986', '1990', '2018', '1977', '1982',
#        '1980', '1993', '1984', '1985', '1988', '1987', '2005', '1991',
#        '2002', '1994', '1992', '1995', '2017', '1997', '1996', '2006',
#        '1999', '1998', '2007', '2008', '2003', '2004', '2010', '2009',
#        '2011', '2013', '2012', '2016', '2015', '2014', '2019', '2020',
#        'TV Movie 2019'], dtype=object)

# %%
#Crecimieto de peliculas por año
sns.set_style('darkgrid')
plt.figure(figsize=(20,15))
sns.histplot(Peliculas.year,kde=False);

# %%
Peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85846 entries, 0 to 85845
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      85846 non-null  object
#  1   year                       85846 non-null  object
#  2   genre                      85846 non-null  object
#  3   duration                   85846 non-null  int64
#  4   country                    85785 non-null  object
#  5   language                   85018 non-null  object
#  6   director                   85768 non-null  object
#  7   writer                     84283 non-null  object
#  8   production_company         81397 non-null  object
#  9   actors                     85786 non-null  object
#  10  description                83731 non-null  object
#  11  avg_vote                   85846 non-null  float64
#  12  votes                      85846 non-null  int64
#  13  budget                     23709 non-null  object
#  14  usa_gross_income           15325 non-null  object
#  15  worlwide_gross_income      31015 non-null  object
#  16  metascore                  13305 non-null  float64
#  17  reviews_from_users         78251 non-null  float64
#  18  reviews_from_critics       74057 non-null  float64
#  19  allgenders_0age_avg_vote   33358 non-null  float64
#  20  allgenders_18age_avg_vote  85140 non-null  float64
#  21  allgenders_30age_avg_vote  85836 non-null  float64
#  22  allgenders_45age_avg_vote  85766 non-null  float64
#  23  males_allages_avg_vote     85845 non-null  float64
#  24  males_0age_avg_vote        27410 non-null  float64
#  25  males_18age_avg_vote       84381 non-null  float64
#  26  males_30age_avg_vote       85834 non-null  float64
#  27  males_45age_avg_vote       85745 non-null  float64
#  28  females_allages_avg_vote   85765 non-null  float64
#  29  females_0age_avg_vote      22117 non-null  float64
#  30  females_18age_avg_vote     79326 non-null  float64
#  31  females_30age_avg_vote     84902 non-null  float64
#  32  females_45age_avg_vote     83048 non-null  float64
# dtypes: float64(18), int64(2), object(13)
# memory usage: 21.6+ MB

# %%
## Ratios Metascore

### Nota: El metascore es un ratio que evalua la calidad objetiva de las peliculas, no es una puntuación por critica

# %%
rating_freq = Peliculas['metascore'].value_counts()

plt.figure(figsize=(15,10))
rating_freq.plot.bar(color='teal',alpha=0.5)
plt.xticks(rotation=50)
plt.xlabel("Ratings")
plt.ylabel("Frequency of ratings")
plt.title("Rating Frequency Metascore")
plt.show()
plt.close()

# %%
## ¿Que países generan más contenido?

# %%
country_codes = {'afghanistan': 'AFG',
 'albania': 'ALB',
 'algeria': 'DZA',
 'american samoa': 'ASM',
 'andorra': 'AND',
 'angola': 'AGO',
 'anguilla': 'AIA',
 'antigua and barbuda': 'ATG',
 'argentina': 'ARG',
 'armenia': 'ARM',
 'aruba': 'ABW',
 'australia': 'AUS',
 'austria': 'AUT',
 'azerbaijan': 'AZE',
 'bahamas': 'BHM',
 'bahrain': 'BHR',
 'bangladesh': 'BGD',
 'barbados': 'BRB',
 'belarus': 'BLR',
 'belgium': 'BEL',
 'belize': 'BLZ',
 'benin': 'BEN',
 'bermuda': 'BMU',
 'bhutan': 'BTN',
 'bolivia': 'BOL',
 'bosnia and herzegovina': 'BIH',
 'botswana': 'BWA',
 'brazil': 'BRA',
 'british virgin islands': 'VGB',
 'brunei': 'BRN',
 'bulgaria': 'BGR',
 'burkina faso': 'BFA',
 'burma': 'MMR',
 'burundi': 'BDI',
 'cabo verde': 'CPV',
 'cambodia': 'KHM',
 'cameroon': 'CMR',
 'canada': 'CAN',
 'cayman islands': 'CYM',
 'central african republic': 'CAF',
 'chad': 'TCD',
 'chile': 'CHL',
 'china': 'CHN',
 'colombia': 'COL',
 'comoros': 'COM',
 'congo democratic': 'COD',
 'Congo republic': 'COG',
 'cook islands': 'COK',
 'costa rica': 'CRI',
 "cote d'ivoire": 'CIV',
 'croatia': 'HRV',
 'cuba': 'CUB',
 'curacao': 'CUW',
 'cyprus': 'CYP',
 'czech republic': 'CZE',
 'denmark': 'DNK',
 'djibouti': 'DJI',
 'dominica': 'DMA',
 'dominican republic': 'DOM',
 'ecuador': 'ECU',
 'egypt': 'EGY',
 'el salvador': 'SLV',
 'equatorial guinea': 'GNQ',
 'eritrea': 'ERI',
 'estonia': 'EST',
 'ethiopia': 'ETH',
 'falkland islands': 'FLK',
 'faroe islands': 'FRO',
 'fiji': 'FJI',
 'finland': 'FIN',
 'france': 'FRA',
 'french polynesia': 'PYF',
 'gabon': 'GAB',
 'gambia, the': 'GMB',
 'georgia': 'GEO',
 'germany': 'DEU',
 'ghana': 'GHA',
 'gibraltar': 'GIB',
  'greece': 'GRC',
 'greenland': 'GRL',
 'grenada': 'GRD',
 'guam': 'GUM',
 'guatemala': 'GTM',
 'guernsey': 'GGY',
 'guinea-bissau': 'GNB',
 'guinea': 'GIN',
 'guyana': 'GUY',
 'haiti': 'HTI',
 'honduras': 'HND',
 'hong kong': 'HKG',
 'hungary': 'HUN',
 'iceland': 'ISL',
 'india': 'IND',
 'indonesia': 'IDN',
 'iran': 'IRN',
 'iraq': 'IRQ',
 'ireland': 'IRL',
 'isle of man': 'IMN',
 'israel': 'ISR',
 'italy': 'ITA',
 'jamaica': 'JAM',
 'japan': 'JPN',
 'jersey': 'JEY',
 'jordan': 'JOR',
 'kazakhstan': 'KAZ',
 'kenya': 'KEN',
 'kiribati': 'KIR',
 'north korea': 'PRK',
 'south korea': 'KOR',
 'kosovo': 'KSV',
 'kuwait': 'KWT',
 'kyrgyzstan': 'KGZ',
 'laos': 'LAO',
 'latvia': 'LVA',
 'lebanon': 'LBN',
 'lesotho': 'LSO',
 'liberia': 'LBR',
 'libya': 'LBY',
 'liechtenstein': 'LIE',
 'lithuania': 'LTU',
 'luxembourg': 'LUX',
 'macau': 'MAC',
 'macedonia': 'MKD',
 'madagascar': 'MDG',
 'malawi': 'MWI',
 'malaysia': 'MYS',
 'maldives': 'MDV',
 'mali': 'MLI',
 'malta': 'MLT',
 'marshall islands': 'MHL',
 'mauritania': 'MRT',
 'mauritius': 'MUS',
 'mexico': 'MEX',
 'micronesia': 'FSM',
 'moldova': 'MDA',
 'monaco': 'MCO',
 'mongolia': 'MNG',
 'montenegro': 'MNE',
 'morocco': 'MAR',
 'mozambique': 'MOZ',
 'namibia': 'NAM',
 'nepal': 'NPL',
 'netherlands': 'NLD',
 'new caledonia': 'NCL',
 'new zealand': 'NZL',
 'nicaragua': 'NIC',
 'nigeria': 'NGA',
 'niger': 'NER',
 'niue': 'NIU',
 'northern mariana islands': 'MNP',
 'norway': 'NOR',
 'oman': 'OMN',
 'pakistan': 'PAK',
 'palau': 'PLW',
 'panama': 'PAN',
 'papua new guinea': 'PNG',
 'paraguay': 'PRY',
 'peru': 'PER',
 'philippines': 'PHL',
 'poland': 'POL',
 'portugal': 'PRT',
 'puerto rico': 'PRI',
 'qatar': 'QAT',
 'romania': 'ROU',
 'russia': 'RUS',
 'rwanda': 'RWA',
 'saint kitts and nevis': 'KNA',
 'saint lucia': 'LCA',
 'saint martin': 'MAF',
 'saint pierre and miquelon': 'SPM',
 'saint vincent and the grenadines': 'VCT',               
 'samoa': 'WSM',
 'san marino': 'SMR',
 'sao tome and principe': 'STP',
 'saudi arabia': 'SAU',
 'senegal': 'SEN',
 'serbia': 'SRB',
 'seychelles': 'SYC',
 'sierra leone': 'SLE',
 'singapore': 'SGP',
 'sint maarten': 'SXM',
 'slovakia': 'SVK',
 'slovenia': 'SVN',
 'solomon islands': 'SLB',
 'somalia': 'SOM',
 'south africa': 'ZAF',
 'south sudan': 'SSD',
 'spain': 'ESP',
 'sri lanka': 'LKA',
 'sudan': 'SDN',
 'suriname': 'SUR',
 'swaziland': 'SWZ',
 'sweden': 'SWE',
 'switzerland': 'CHE',
 'syria': 'SYR',
 'taiwan': 'TWN',
 'tajikistan': 'TJK',
 'tanzania': 'TZA',
 'thailand': 'THA',
 'timor-leste': 'TLS',
 'togo': 'TGO',
 'tonga': 'TON',
 'trinidad and tobago': 'TTO',
 'tunisia': 'TUN',
 'turkey': 'TUR',
 'turkmenistan': 'TKM',
 'tuvalu': 'TUV',
 'uganda': 'UGA',
 'ukraine': 'UKR',
 'united arab emirates': 'ARE',
 'united kingdom': 'GBR',
 'united states': 'USA',
 'uruguay': 'URY',
 'uzbekistan': 'UZB',
 'vanuatu': 'VUT',
 'venezuela': 'VEN',
 'vietnam': 'VNM',
 'virgin islands': 'VGB',
 'west bank': 'WBG',
 'yemen': 'YEM',
 'zambia': 'ZMB',
 'zimbabwe': 'ZWE'}

# %%
colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"]

# %%
def geoplot(ddf):
    country_codes, country = {}, {}
    shows_countries = ", ".join(ddf['country'].dropna()).split(", ")
    for c,v in dict(Counter(shows_countries)).items():
        code = ""
        if c.lower() in country_codes:
            code = country_codes[c.lower()]
        country_codes[code] = v
        country[c] = v
data = [dict(
            type = 'choropleth',
            locations = list(country_codes.keys()),
            z = list(country_codes.values()),
            colorscale = [[0,"rgb(5, 10, 172)"],[0.65,"rgb(40, 60, 190)"],[0.75,"rgb(70, 100, 245)"],\
                        [0.80,"rgb(90, 120, 245)"],[0.9,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
            autocolorscale = False,
            reversescale = True,
            marker = dict(
                line = dict (
                    color = 'gray',
                    width = 0.5
                ) ),
            colorbar = dict(
                autotick = False,
                title = ''),
          ) ]

# %%
data = [dict(type = 'choropleth',
             locations = list(country_codes.keys()),z = list(country_codes.values()),
            colorscale = [[0,"rgb(5, 10, 172)"],[0.65,"rgb(40, 60, 190)"],[0.75,"rgb(70, 100, 245)"],\
                        [0.80,"rgb(90, 120, 245)"],[0.9,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
            autocolorscale = False,
            reversescale = True,
            marker = dict(
                line = dict (
                    color = 'gray',
                    width = 0.5
                ) ),
            colorbar = dict(
                autotick = False,
                title = ''),
          ) ]
fig = dict( data=data, layout=layout )
    iplot( fig, validate=False, filename='d3-world-map' )
    return country
# Out:
#   File "<ipython-input-53-44a52d2de8ec>", line 17
#     iplot( fig, validate=False, filename='d3-world-map' )
#     ^
# IndentationError: unexpected indent

# %%
fig = dict( data=data, layout=layout )
    iplot( fig, validate=False, filename='d3-world-map' )
    return country
# Out:
#   File "<ipython-input-52-fbaf371eb8b7>", line 2
#     iplot( fig, validate=False, filename='d3-world-map' )
#     ^
# IndentationError: unexpected indent

# %%
fig = dict( data=data, layout=layout )
    iplot( fig, validate=False)
    return country

country_vals = geoplot(df)
tabs = Counter(country_vals).most_common(25)

labels = [_[0] for _ in tabs][::-1]
values = [_[1] for _ in tabs][::-1]
trace1 = go.Bar(y=labels, x=values, orientation="h", name="", marker=dict(color="#a678de"))

data = [trace1]
layout = go.Layout(title="Countries with most content", height=700, legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
#   File "<ipython-input-48-5a28f6b0f353>", line 2
#     iplot( fig, validate=False)
#     ^
# IndentationError: unexpected indent

# %%
#function to convert to alpah2 country codes and continents
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    return (cn_a2_code, cn_continent)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-110-9da5e42b1ef3> in <module>
#       1 #function to convert to alpah2 country codes and continents
# ----> 2 from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
#       3 def get_continent(col):
#       4     try:
#       5         cn_a2_code =  country_name_to_country_alpha2(col)
#
# ModuleNotFoundError: No module named 'pycountry_convert'
